# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

full_health_data = pd.read_csv('C://Users/jray/Desktop/Ray/Plotting/vlass_vcss_z_var_blazar.csv', header=0, sep=",")
correlation_full_health = full_health_data.corr()

axis_corr = sns.heatmap(
correlation_full_health,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()

# %%
import pandas as pd

full_health_data = pd.read_csv("C://Users/jray/Desktop/Ray/Plotting/vlass_vcss_z_var_blazar.csv", header=0, sep=",")

Corr_Matrix = round(full_health_data.corr(),2)

print(Corr_Matrix)
# Out:
#          RA avg  Dec avg  SE 1  SE 2  SE 3    EL  Isl rms 1  Isl rms 2  \
# RA avg     1.00    -0.00 -0.01 -0.11  0.14  0.37       0.02       0.06
# Dec avg   -0.00     1.00 -0.50 -0.08  0.09  0.81      -0.08      -0.14
# SE 1      -0.01    -0.50  1.00  0.00 -0.14 -0.39      -0.09       0.05
# SE 2      -0.11    -0.08  0.00  1.00 -0.72 -0.21       0.02      -0.15
# SE 3       0.14     0.09 -0.14 -0.72  1.00  0.24      -0.05       0.15
# ...         ...      ...   ...   ...   ...   ...        ...        ...
# FX        -0.02     0.00  0.01 -0.02 -0.02 -0.02       0.02      -0.00
# Fgam       0.06    -0.03 -0.02 -0.11  0.04  0.03       0.26       0.11
# RA_4       1.00    -0.00 -0.01 -0.11  0.14  0.37       0.02       0.06
# DEC_4     -0.00     1.00 -0.50 -0.08  0.09  0.81      -0.08      -0.14
# Z_4        0.03     0.03  0.05  0.03 -0.06  0.07      -0.01       0.05
#
#          Isl rms 3  Mean Isl 1  ...   DEs   z_3  Rmag  F1.4  F143    FX  Fgam  \
# ...

# %%
df = pd.DataFrame(Corr_Matrix)
df.to_csv('corr_2.csv', index=True, header=True)
